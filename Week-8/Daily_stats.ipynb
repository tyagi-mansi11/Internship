# %% [markdown]
# # **Part-1: Daily Stats EDA**
#
# ---

# %% [markdown]
# ## Overview of the Dataset (daily_stats_data)

# %%
# Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Loading dataset
first_df = pd.read_csv('/content/daily_stats_data.csv')
df = first_df.copy()

# %%
# get first rows of dataset
df.head()
# Out:
#            id activity_date  daily_average_heartrate  total_steps  \
# 0  1503960366    2016-04-12                      NaN        13162
# 1  1503960366    2016-04-13                      NaN        10735
# 2  1503960366    2016-04-14                      NaN        10460
# 3  1503960366    2016-04-15                      NaN         9762
# 4  1503960366    2016-04-16                      NaN        12669
#
#    total_distance  tracker_distance  logged_activities_distance  \
# 0            8.50              8.50                         0.0
# 1            6.97              6.97                         0.0
# 2            6.74              6.74                         0.0
# 3            6.28              6.28                         0.0
# 4            8.16              8.16                         0.0
#
#    very_active_distance  moderately_active_distance  light_active_distance  \
# 0                  1.88                        0.55                   6.06
# ...

# %%
# get columns names
df.columns
# Out:
# Index(['id', 'activity_date', 'daily_average_heartrate', 'total_steps',
#        'total_distance', 'tracker_distance', 'logged_activities_distance',
#        'very_active_distance', 'moderately_active_distance',
#        'light_active_distance', 'sedentary_active_distance',
#        'very_active_minutes', 'fairly_active_minutes',
#        'lightly_active_minutes', 'sedentary_minutes', 'calories',
#        'total_minutes_asleep', 'total_sleep_records', 'total_time_in_bed',
#        'bmi', 'weight_kg', 'weight_pounds'],
#       dtype='object')

# %%
df.info(verbose =True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          940 non-null    int64
#  1   activity_date               940 non-null    object
#  2   daily_average_heartrate     334 non-null    float64
#  3   total_steps                 940 non-null    int64
#  4   total_distance              940 non-null    float64
#  5   tracker_distance            940 non-null    float64
#  6   logged_activities_distance  940 non-null    float64
#  7   very_active_distance        940 non-null    float64
#  8   moderately_active_distance  940 non-null    float64
#  9   light_active_distance       940 non-null    float64
#  10  sedentary_active_distance   940 non-null    float64
#  11  very_active_minutes         940 non-null    int64
#  12  fairly_active_minutes       940 non-null    int64
# ...

# %% [markdown]
# # **Data Visualization**
#
# ---

# %%
# Bar plot

fig = px.bar(df, x='activity_date', y='daily_average_heartrate', title='Relationship between daily activity and heart rate',
labels={'activity_date': 'Activity Date',
        'daily_average_heartrate': 'Daily Average Heartrate'},
        color_discrete_sequence=['yellowgreen'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Bar plot

fig = px.bar(df, x='activity_date', y='total_steps', title='Relationship between daily activity and total steps taken',
labels={'activity_date': 'Activity Date',
        'total_steps': 'Total Steps'},
        color_discrete_sequence=['blueviolet'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Scatter Plot

fig1 = px.scatter(df, x='total_steps', y='total_distance', title='Relationship between movement and measurement',
                  labels={'Total_steps', 'Total_distance'},
                  color_discrete_sequence=['slateblue'])
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Pair Plot
fig = px.scatter_matrix(df[['total_steps', 'total_distance','fairly_active_minutes']],
                        title='Daily Fitness Snapshot',
                        labels={'total_steps':'Total Steps', 'total_distance':'Total Distance', 'fairly_active_minutes':'Fairly active mins'},
                        color_discrete_sequence=['sandybrown'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Stacked bar chat

fig = px.bar(df, x = 'activity_date', y=['fairly_active_minutes', 'very_active_minutes', 'lightly_active_minutes'],
             title='Comparing low, moderate, and high-intensity activity')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 # Correlation Matrix

cols = ['total_steps', 'total_distance', 'tracker_distance', 'logged_activities_distance', 'sedentary_active_distance']
first_df = df[cols]
matrix = first_df.corr()
fig = px.imshow(matrix, labels=dict(color="Correlation"), x = matrix.index, y = matrix.columns, color_continuous_scale = 'matter')
fig.update_layout(title_text='Analysis of Step Count and Distance Correlation via a Correlation Matrix')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
