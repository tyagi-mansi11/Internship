# %% [markdown]
# # **Week-7: Air Quality**
#
# ---

# %% [markdown]
# # Getting overview of Dataset

# %%
# Import Libraries

import pandas as pd
import numpy as np

# %%
# Loading dataset

first = pd.read_csv('/content/data.csv',encoding='unicode_escape')
data_df = first.copy()
# Out:
# <ipython-input-22-43157e71f719>:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   first = pd.read_csv('/content/data.csv',encoding='unicode_escape')

# %%
# Get first rows of dataset
data_df.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date
# 0                         NaN    NaN  1990-02-01
# 1                         NaN    NaN  1990-02-01
# 2                         NaN    NaN  1990-02-01
# 3                         NaN    NaN  1990-03-01
# 4                         NaN    NaN  1990-03-01

# %%
# Get last rows of dataset
data_df.tail()
# Out:
#        stn_code sampling_date      state   location agency              type  \
# 137724      NaN     13/2/2006  Karnataka  Bangalore    NaN  Industrial Areas
# 137725      NaN     16/2/2006  Karnataka  Bangalore    NaN  Industrial Areas
# 137726      NaN     20/2/2006  Karnataka  Bangalore    NaN  Industrial Areas
# 137727      NaN     23/2/2006  Karnataka  Bangalore    NaN  Industrial Areas
# 137728      NaN     27/2/2006  Karnataka  Bangalore    NaN  Industrial Areas
#
#          so2   no2   rspm    spm location_monitoring_station  pm2_5  \
# 137724  29.2  39.4  189.0  459.0              Graphite India    NaN
# 137725  23.2  43.7  113.0  311.0              Graphite India    NaN
# 137726  29.3  43.3   98.0  293.0              Graphite India    NaN
# 137727  27.3  41.4  116.0  289.0              Graphite India    NaN
# 137728  24.4  43.3   97.0  261.0                         Gra    NaN
#
#               date
# 137724  2006-02-13
# 137725  2006-02-16
# 137726  2006-02-20
# 137727  2006-02-23
# 137728         NaN

# %%
# Get columns names
data_df.columns
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
# Get datatypes of all columns
data_df.dtypes
# Out:
# stn_code                        object
# sampling_date                   object
# state                           object
# location                        object
# agency                          object
# type                            object
# so2                            float64
# no2                            float64
# rspm                           float64
# spm                            float64
# location_monitoring_station     object
# pm2_5                          float64
# date                            object
# dtype: object

# %%
# Get no. of rows and columns
data_df.shape
# Out:
# (137729, 13)

# %%
data_df.info(verbose =True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137729 entries, 0 to 137728
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     89893 non-null   object
#  1   sampling_date                137729 non-null  object
#  2   state                        137729 non-null  object
#  3   location                     137729 non-null  object
#  4   agency                       88361 non-null   object
#  5   type                         136101 non-null  object
#  6   so2                          123364 non-null  float64
#  7   no2                          131719 non-null  float64
#  8   rspm                         123254 non-null  float64
#  9   spm                          67267 non-null   float64
#  10  location_monitoring_station  128178 non-null  object
#  11  pm2_5                        4249 non-null    float64
#  12  date                         137728 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 13.7+ MB

# %%
# check for null values in all columns
data_df.isna().sum()
# Out:
# stn_code                        47836
# sampling_date                       0
# state                               0
# location                            0
# agency                          49368
# type                             1628
# so2                             14365
# no2                              6010
# rspm                            14475
# spm                             70462
# location_monitoring_station      9551
# pm2_5                          133480
# date                                1
# dtype: int64

# %% [markdown]
# # Data Cleaning
#
# ---

# %%
# Drop column

data_df.drop(columns=['stn_code','agency','location_monitoring_station'], inplace=True)
data_df.head(2)
# Out:
#         sampling_date           state   location  \
# 0  February - M021990  Andhra Pradesh  Hyderabad
# 1  February - M021990  Andhra Pradesh  Hyderabad
#
#                                  type  so2   no2  rspm  spm  pm2_5        date
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN    NaN  1990-02-01
# 1                     Industrial Area  3.1   7.0   NaN  NaN    NaN  1990-02-01

# %%
data_df['rspm'] = data_df['rspm'].replace(np.nan, data_df.rspm.median())

# %%
data_df['spm'] = data_df['spm'].replace(np.nan, data_df.spm.median())

# %%
data_df['so2'] = data_df['so2'].replace(np.nan, data_df.so2.median())

# %%
data_df['no2'] = data_df['no2'].replace(np.nan, data_df.no2 .median())

# %%
data_df.isna().sum()
# Out:
# sampling_date         0
# state                 0
# location              0
# type               1628
# so2                   0
# no2                   0
# rspm                  0
# spm                   0
# pm2_5            133480
# date                  1
# dtype: int64

# %%
data_df['pm2_5'] = data_df['pm2_5'].replace(np.nan, ' ')

# %%
data_df['type'] = data_df['type'].replace(np.nan, ' ')

# %%
data_df.info(verbose =True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137729 entries, 0 to 137728
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   sampling_date  137729 non-null  object
#  1   state          137729 non-null  object
#  2   location       137729 non-null  object
#  3   type           137729 non-null  object
#  4   so2            137729 non-null  float64
#  5   no2            137729 non-null  float64
#  6   rspm           137729 non-null  float64
#  7   spm            137729 non-null  float64
#  8   pm2_5          137729 non-null  object
#  9   date           137728 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 10.5+ MB

# %%
data_df['date'] = pd.to_datetime(data_df['date']).dt.date

# %%
data_df['year'] = pd.to_datetime(data_df['date']).dt.year

# %%
data_df['date'] = data_df['date'].replace(np.nan, ' ')
data_df['year'] = data_df['year'].replace(np.nan, ' ')

# %%
data_df.isna().sum()
# Out:
# sampling_date    0
# state            0
# location         0
# type             0
# so2              0
# no2              0
# rspm             0
# spm              0
# pm2_5            0
# date             0
# year             0
# dtype: int64

# %%
data_df.head()
# Out:
#         sampling_date           state   location  \
# 0  February - M021990  Andhra Pradesh  Hyderabad
# 1  February - M021990  Andhra Pradesh  Hyderabad
# 2  February - M021990  Andhra Pradesh  Hyderabad
# 3     March - M031990  Andhra Pradesh  Hyderabad
# 4     March - M031990  Andhra Pradesh  Hyderabad
#
#                                  type  so2   no2  rspm    spm pm2_5  \
# 0  Residential, Rural and other Areas  4.8  17.4  87.0  187.0
# 1                     Industrial Area  3.1   7.0  87.0  187.0
# 2  Residential, Rural and other Areas  6.2  28.5  87.0  187.0
# 3  Residential, Rural and other Areas  6.3  14.7  87.0  187.0
# 4                     Industrial Area  4.7   7.5  87.0  187.0
#
#          date    year
# 0  1990-02-01  1990.0
# 1  1990-02-01  1990.0
# 2  1990-02-01  1990.0
# 3  1990-03-01  1990.0
# 4  1990-03-01  1990.0

# %%
# To access clean data

data_df.to_csv('cleaned_data.csv', index = False)
print("Saved")
# Out:
# Saved

# %%
from google.colab import files
files.download("cleaned_data.csv")
